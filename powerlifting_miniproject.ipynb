# %% [markdown]
# <a href="https://colab.research.google.com/github/sivasamy1/data_analytic/blob/main/powerlifting_miniproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from tabulate import tabulate


url = "/content/openpowerlifting-2021-12-10-b420db66 (1).csv"
df = pd.read_csv(url)
# Out:
# <ipython-input-69-6de38023fdf0>:7: DtypeWarning: Columns (33,35,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)

# %%
print(df)
# Out:
#                           Name Sex Event Equipment   Age AgeClass  \
# 0                  Alona Vladi   F   SBD       Raw  33.0    24-34
# 1           Galina Solovyanova   F   SBD       Raw  43.0    40-44
# 2               Daniil Voronin   M   SBD       Raw  15.5    16-17
# 3               Aleksey Krasov   M   SBD       Raw  35.0    35-39
# 4       Margarita Pleschenkova   M   SBD       Raw  26.5    24-34
# ...                        ...  ..   ...       ...   ...      ...
# 146336          Ruslan Adgamov   M     D       Raw  23.0    20-23
# 146337            Nikolay Lyan   M     D       Raw  21.0    20-23
# 146338         Artur Khusainov   M     D       Raw  34.0    24-34
# 146339          Ivan Prokhorov   M     D       Raw  19.0    18-19
# 146340          Rustam Muradov   M     D       Raw  25.0    24-34
#
#        BirthYearClass            Division  BodyweightKg WeightClassKg  ...  \
# 0               24-39                   O         58.30            60  ...
# 1               40-49                  M1         73.10            75  ...
# 2               14-18                   T         67.40            75  ...
# 3               24-39                   O         66.65            75  ...
# 4               24-39                   O         72.45            75  ...
# ...               ...                 ...           ...           ...  ...
# 146336          19-23        Amateur Open         71.30            75  ...
# 146337          19-23        Amateur Open         79.80          82.5  ...
# 146338          24-39        Amateur Open         80.90          82.5  ...
# 146339          19-23  Amateur Teen 18-19         84.00            90  ...
# 146340          24-39        Amateur Open         88.90            90  ...
#
#         Tested  Country  State  Federation  ParentFederation        Date  \
# 0          Yes   Russia    NaN         GFP               NaN  2019-05-11
# 1          Yes   Russia    NaN         GFP               NaN  2019-05-11
# 2          Yes   Russia    NaN         GFP               NaN  2019-05-11
# 3          Yes   Russia    NaN         GFP               NaN  2019-05-11
# 4          Yes   Russia    NaN         GFP               NaN  2019-05-11
# ...        ...      ...    ...         ...               ...         ...
# 146336     Yes   Russia    NaN     WPC-RUS               WPC  2016-10-22
# 146337     Yes   Russia    NaN     WPC-RUS               WPC  2016-10-22
# 146338     Yes   Russia    NaN     WPC-RUS               WPC  2016-10-22
# 146339     Yes   Russia    NaN     WPC-RUS               WPC  2016-10-22
# 146340     Yes       Ru    NaN         NaN               NaN         NaN
#
#         MeetCountry  MeetState  MeetTown                     MeetName
# 0            Russia        NaN   Bryansk              Open Tournament
# 1            Russia        NaN   Bryansk              Open Tournament
# 2            Russia        NaN   Bryansk              Open Tournament
# 3            Russia        NaN   Bryansk              Open Tournament
# 4            Russia        NaN   Bryansk              Open Tournament
# ...             ...        ...       ...                          ...
# 146336       Russia         TA     Kazan  Open Horizons Tatarstan Cup
# 146337       Russia         TA     Kazan  Open Horizons Tatarstan Cup
# 146338       Russia         TA     Kazan  Open Horizons Tatarstan Cup
# 146339       Russia         TA     Kazan  Open Horizons Tatarstan Cup
# 146340          NaN        NaN       NaN                          NaN
#
# [146341 rows x 41 columns]

# %%
# header
list(df)
# Out:
# ['Name',
#  'Sex',
#  'Event',
#  'Equipment',
#  'Age',
#  'AgeClass',
#  'BirthYearClass',
#  'Division',
#  'BodyweightKg',
#  'WeightClassKg',
#  'Squat1Kg',
#  'Squat2Kg',
#  'Squat3Kg',
#  'Squat4Kg',
#  'Best3SquatKg',
#  'Bench1Kg',
#  'Bench2Kg',
#  'Bench3Kg',
#  'Bench4Kg',
#  'Best3BenchKg',
#  'Deadlift1Kg',
#  'Deadlift2Kg',
#  'Deadlift3Kg',
#  'Deadlift4Kg',
#  'Best3DeadliftKg',
#  'TotalKg',
#  'Place',
#  'Dots',
#  'Wilks',
#  'Glossbrenner',
#  'Goodlift',
#  'Tested',
#  'Country',
#  'State',
#  'Federation',
#  'ParentFederation',
#  'Date',
#  'MeetCountry',
#  'MeetState',
#  'MeetTown',
#  'MeetName']

# %%
from matplotlib import pyplot as plt

df.groupby("Dots")["State"].count()
# Out:
# Dots
# 10.17     0
# 10.21     0
# 11.88     0
# 12.71     0
# 13.69     0
#          ..
# 639.02    0
# 640.53    0
# 658.08    1
# 671.85    0
# 686.88    1
# Name: State, Length: 37651, dtype: int64

# %%
df_men = df1[df1['Sex'] == 'M']
top_10_states_men = df_men['State'].value_counts().head(10)
print(top_10_states_men)
# Out:
# State
# QLD    21
# NSW    10
# VIC    10
# TAS     3
# SA      1
# WA      1
# Name: count, dtype: int64

# %%
df_women = df1[df1['Sex'] == 'F']
top_10_states_women = df_women['State'].value_counts().head(10)
print(top_10_states_women)
# Out:
# State
# VIC    3
# NSW    1
# QLD    1
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df = pd.read_csv(url)

# Convert 'Date' to datetime and 'Age' to numeric
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')
# Out:
# <ipython-input-75-f27a9c55d337>:6: DtypeWarning: Columns (33,35,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)

# %%
# Top 10 states for Men
df_men_states = df[df["Sex"] == "M"].groupby(["State"]).size().to_frame("count").reset_index()
df_men_sorted = df_men_states.sort_values(by="count", ascending=False)
print("Top 10 states for Men")
print(tabulate(df_men_sorted.head(10), headers='keys', tablefmt='psql'))
# Out:
# Top 10 states for Men
# +----+---------+---------+
# |    | State   |   count |
# |----+---------+---------|
# | 62 | VA      |    1621 |
# | 35 | NC      |    1562 |
# | 49 | PA      |    1276 |
# | 27 | MD      |     585 |
# | 44 | NY      |     470 |
# | 71 | YNE     |     454 |
# |  3 | AZ      |     436 |
# | 11 | EM      |     281 |
# | 15 | GL      |     271 |
# | 40 | NM      |     267 |
# +----+---------+---------+

# %%
# Top 10 states for Women
df_women_states = df[df["Sex"] == "F"].groupby(["State"]).size().to_frame("count").reset_index()
df_women_sorted = df_women_states.sort_values(by="count", ascending=False)
print("Top 10 states for Women")
print(tabulate(df_women_sorted.head(10), headers='keys', tablefmt='psql'))
# Out:
# Top 10 states for Women
# +----+---------+---------+
# |    | State   |   count |
# |----+---------+---------|
# | 49 | VA      |     717 |
# | 27 | NC      |     611 |
# | 39 | PA      |     397 |
# | 11 | EM      |     197 |
# | 31 | NM      |     186 |
# |  3 | AZ      |     180 |
# | 35 | NY      |     169 |
# | 21 | MD      |     165 |
# | 57 | YNE     |     162 |
# | 46 | SW      |     148 |
# +----+---------+---------+

# %%
# Data for Top 21-30 states for Men
data_men_states = {"OK": 5075, "BC": 4823, "TN": 4680, "OR": 4632, "NM": 4364,
                    "MI": 4330, "AB": 4184, "AL": 4184, "IN": 4036, "NV": 3746}

# %%
# Pie chart for Men Top 21-30 states
plt.pie(list(data_men_states.values()), labels=data_men_states.keys(), autopct='%2.1f%%', shadow=True, startangle=0)
plt.axis("equal")
plt.show()

# %%
# Bar chart for Men Top 21-30 states
plt.bar(data_men_states.keys(), data_men_states.values(), color="blue")
plt.xlabel("States")
plt.ylabel("Number of Male Powerlifters")
plt.title("Bar Chart For Top 21 to 30 States for Men")
plt.xticks(rotation=90)
plt.show()

# %%
# Data for Top 21-30 states for Women
data_women_states = {"IL": 2184, "MA": 2174, "NJ": 2169, "MI": 2115, "AB": 1870,
                      "BC": 1744, "IN": 1733, "HI": 1717, "AL": 1343, "OK": 1337}

# %%
# Pie chart for Women Top 21-30 states
plt.pie(list(data_women_states.values()), labels=data_women_states.keys(), autopct='%2.1f%%', shadow=True, startangle=0)
plt.axis("equal")
plt.show()

# %%
# Bar chart for Women Top 21-30 states
plt.bar(data_women_states.keys(), data_women_states.values(), color="blue")
plt.xlabel("States")
plt.ylabel("Number of Women Powerlifters")
plt.title("Bar Chart For Top 21 to 30 States for Women")
plt.xticks(rotation=0)
plt.show()
