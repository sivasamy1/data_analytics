# %% [markdown]
# <a href="https://colab.research.google.com/github/sivasamy1/data_analytic/blob/main/powerlifting_miniproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from tabulate import tabulate


url = "/content/drive/MyDrive/powerlifting/openpowerlifting-2021-12-10-b420db66.csv"
df = pd.read_csv(url)
# Out:
# <ipython-input-5-6f1e86cfbfa5>:7: DtypeWarning: Columns (33,35,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)

# %%
print(df)
# Out:
#                            Name Sex Event   Equipment   Age AgeClass  \
# 0                   Alona Vladi   F   SBD         Raw  33.0    24-34
# 1            Galina Solovyanova   F   SBD         Raw  43.0    40-44
# 2                Daniil Voronin   M   SBD         Raw  15.5    16-17
# 3                Aleksey Krasov   M   SBD         Raw  35.0    35-39
# 4        Margarita Pleschenkova   M   SBD         Raw  26.5    24-34
# ...                         ...  ..   ...         ...   ...      ...
# 2569941            Inna Orobets   F   SBD  Single-ply  45.0    45-49
# 2569942             Ágnes Szabó   F   SBD  Single-ply  27.5    24-34
# 2569943   Brenda van der Meulen   F   SBD  Single-ply  37.5    35-39
# 2569944            Kelly Phasey   F   SBD  Single-ply  39.5    35-39
# 2569945  Hildeborg Juvet Hugdal   F   SBD  Single-ply  32.5    24-34
#
#         BirthYearClass Division  BodyweightKg WeightClassKg  ...  Tested  \
# 0                24-39        O         58.30            60  ...     Yes
# 1                40-49       M1         73.10            75  ...     Yes
# 2                14-18        T         67.40            75  ...     Yes
# 3                24-39        O         66.65            75  ...     Yes
# 4                24-39        O         72.45            75  ...     Yes
# ...                ...      ...           ...           ...  ...     ...
# 2569941          40-49     Open        109.30           84+  ...     Yes
# 2569942          24-39     Open        113.22           84+  ...     Yes
# 2569943          24-39     Open        110.79           84+  ...     Yes
# 2569944          40-49     Open        124.53           84+  ...     Yes
# 2569945          24-39     Open        123.00           84+  ...     Yes
#
#              Country  State  Federation  ParentFederation        Date  \
# 0             Russia    NaN         GFP               NaN  2019-05-11
# 1             Russia    NaN         GFP               NaN  2019-05-11
# 2             Russia    NaN         GFP               NaN  2019-05-11
# 3             Russia    NaN         GFP               NaN  2019-05-11
# 4             Russia    NaN         GFP               NaN  2019-05-11
# ...              ...    ...         ...               ...         ...
# 2569941      Ukraine    NaN         IPF               IPF  2016-11-14
# 2569942      Hungary    NaN         IPF               IPF  2016-11-14
# 2569943  Netherlands    NaN         IPF               IPF  2016-11-14
# 2569944      England    NaN         IPF               IPF  2016-11-14
# 2569945       Norway    NaN         IPF               IPF  2016-11-14
#
#          MeetCountry  MeetState  MeetTown                  MeetName
# 0             Russia        NaN   Bryansk           Open Tournament
# 1             Russia        NaN   Bryansk           Open Tournament
# 2             Russia        NaN   Bryansk           Open Tournament
# 3             Russia        NaN   Bryansk           Open Tournament
# 4             Russia        NaN   Bryansk           Open Tournament
# ...              ...        ...       ...                       ...
# 2569941          USA        NaN   Orlando  World Open Championships
# 2569942          USA        NaN   Orlando  World Open Championships
# 2569943          USA        NaN   Orlando  World Open Championships
# 2569944          USA        NaN   Orlando  World Open Championships
# 2569945          USA        NaN   Orlando  World Open Championships
#
# [2569946 rows x 41 columns]

# %%
# header
list(df)
# Out:
# ['Name',
#  'Sex',
#  'Event',
#  'Equipment',
#  'Age',
#  'AgeClass',
#  'BirthYearClass',
#  'Division',
#  'BodyweightKg',
#  'WeightClassKg',
#  'Squat1Kg',
#  'Squat2Kg',
#  'Squat3Kg',
#  'Squat4Kg',
#  'Best3SquatKg',
#  'Bench1Kg',
#  'Bench2Kg',
#  'Bench3Kg',
#  'Bench4Kg',
#  'Best3BenchKg',
#  'Deadlift1Kg',
#  'Deadlift2Kg',
#  'Deadlift3Kg',
#  'Deadlift4Kg',
#  'Best3DeadliftKg',
#  'TotalKg',
#  'Place',
#  'Dots',
#  'Wilks',
#  'Glossbrenner',
#  'Goodlift',
#  'Tested',
#  'Country',
#  'State',
#  'Federation',
#  'ParentFederation',
#  'Date',
#  'MeetCountry',
#  'MeetState',
#  'MeetTown',
#  'MeetName']

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby("Dots")["State"].count()
# Out:
# Dots
# 0.68      0
# 1.48      0
# 5.72      0
# 5.92      0
# 5.94      0
#          ..
# 775.33    0
# 776.56    0
# 783.35    1
# 783.48    0
# 795.22    0
# Name: State, Length: 59712, dtype: int64

# %%
df_men = df[df['Sex'] == 'M']
top_10_states_men = df_men['State'].value_counts().head(10)
print(top_10_states_men)
# Out:
# State
# CA    32456
# TX    23517
# OH    11486
# FL    11341
# PA    10857
# NC    10510
# NY     9523
# VA     9312
# ON     9052
# AZ     7632
# Name: count, dtype: int64

# %%
df_women = df[df['Sex'] == 'F']
top_10_states_women = df_women['State'].value_counts().head(10)
print(top_10_states_women)
# Out:
# State
# CA    14639
# TX    11432
# FL     5199
# WI     4396
# WA     4256
# NY     4168
# OH     4110
# PA     4003
# VA     3781
# NC     3744
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df = pd.read_csv(url)

# Convert 'Date' to datetime and 'Age' to numeric
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')
# Out:
# <ipython-input-10-f27a9c55d337>:6: DtypeWarning: Columns (33,35,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)

# %%
# Top 10 states for Men
df_men_states = df[df["Sex"] == "M"].groupby(["State"]).size().to_frame("count").reset_index()
df_men_sorted = df_men_states.sort_values(by="count", ascending=False)
print("Top 10 states for Men")
print(tabulate(df_men_sorted.head(10), headers='keys', tablefmt='psql'))
# Out:
# Top 10 states for Men
# +-----+---------+---------+
# |     | State   |   count |
# |-----+---------+---------|
# |  13 | CA      |   32456 |
# | 114 | TX      |   23517 |
# |  81 | OH      |   11486 |
# |  28 | FL      |   11341 |
# |  85 | PA      |   10857 |
# |  63 | NC      |   10510 |
# |  80 | NY      |    9523 |
# | 116 | VA      |    9312 |
# |  83 | ON      |    9052 |
# |   7 | AZ      |    7632 |
# +-----+---------+---------+

# %%
# Top 10 states for Women
df_women_states = df[df["Sex"] == "F"].groupby(["State"]).size().to_frame("count").reset_index()
df_women_sorted = df_women_states.sort_values(by="count", ascending=False)
print("Top 10 states for Women")
print(tabulate(df_women_sorted.head(10), headers='keys', tablefmt='psql'))
# Out:
# Top 10 states for Women
# +-----+---------+---------+
# |     | State   |   count |
# |-----+---------+---------|
# |  12 | CA      |   14639 |
# | 101 | TX      |   11432 |
# |  25 | FL      |    5199 |
# | 109 | WI      |    4396 |
# | 107 | WA      |    4256 |
# |  71 | NY      |    4168 |
# |  72 | OH      |    4110 |
# |  76 | PA      |    4003 |
# | 103 | VA      |    3781 |
# |  57 | NC      |    3744 |
# +-----+---------+---------+

# %%
# Data for Top 21-30 states for Men
data_men_states = {"OK": 5075, "BC": 4823, "TN": 4680, "OR": 4632, "NM": 4364,
                    "MI": 4330, "AB": 4184, "AL": 4184, "IN": 4036, "NV": 3746}

# %%
# Pie chart for Men Top 21-30 states
plt.pie(list(data_men_states.values()), labels=data_men_states.keys(), autopct='%2.1f%%', shadow=True, startangle=0)
plt.axis("equal")
plt.show()

# %%
# Bar chart for Men Top 21-30 states
plt.bar(data_men_states.keys(), data_men_states.values(), color="blue")
plt.xlabel("States")
plt.ylabel("Number of Male Powerlifters")
plt.title("Bar Chart For Top 21 to 30 States for Men")
plt.xticks(rotation=90)
plt.show()

# %%
# Data for Top 21-30 states for Women
data_women_states = {"IL": 2184, "MA": 2174, "NJ": 2169, "MI": 2115, "AB": 1870,
                      "BC": 1744, "IN": 1733, "HI": 1717, "AL": 1343, "OK": 1337}

# %%
# Pie chart for Women Top 21-30 states
plt.pie(list(data_women_states.values()), labels=data_women_states.keys(), autopct='%2.1f%%', shadow=True, startangle=0)
plt.axis("equal")
plt.show()

# %%
# Bar chart for Women Top 21-30 states
plt.bar(data_women_states.keys(), data_women_states.values(), color="blue")
plt.xlabel("States")
plt.ylabel("Number of Women Powerlifters")
plt.title("Bar Chart For Top 21 to 30 States for Women")
plt.xticks(rotation=0)
plt.show()

# %%
# Convert the 'Date' column to string format
df['Date'] = df['Date'].astype(str)

# Now you can use the .str accessor
def top_10_states_by_year(df, year, sex):
    filtered_df = df[(df['Date'].str.contains(str(year))) & (df['Sex'] == sex)]
    return filtered_df['State'].value_counts().head(10)

# Get top 10 states for men in 2021
top_10_states_men_2021 = top_10_states_by_year(df, 2021, 'M')
print(top_10_states_men_2021)
# Out:
# State
# CA    3384
# TX    3037
# FL    1781
# OH    1529
# PA    1183
# VA    1156
# NC    1109
# NY    1033
# GA     935
# MO     893
# Name: count, dtype: int64

# %%
# Define a custom function to get top 10 states by year and sex
def top_10_states_by_year(df, year, sex):
    filtered_df = df[(df['Date'].str.contains(str(year))) & (df['Sex'] == sex)]
    return filtered_df['State'].value_counts().head(10)

# Get top 10 states for men in 2021
top_10_states_men_2021 = top_10_states_by_year(df, 2021, 'M')
print(top_10_states_men_2021)
# Out:
# State
# CA    3384
# TX    3037
# FL    1781
# OH    1529
# PA    1183
# VA    1156
# NC    1109
# NY    1033
# GA     935
# MO     893
# Name: count, dtype: int64

# %%
# Get top 10 states for women in 2021
top_10_states_women_2021 = top_10_states_by_year(df, 2021, 'F')
print(top_10_states_women_2021)
# Out:
# State
# CA    1578
# TX    1572
# FL     921
# OH     680
# NC     635
# VA     542
# NY     530
# PA     502
# MI     478
# LA     473
# Name: count, dtype: int64

# %%
# Define age bins
bins = [18, 30, 40, 50, 60]
labels = ['18-30', '31-40', '41-50', '51-60']

# Create age groups
df['AgeGroup'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# Group by AgeGroup and Sex, then count
age_sex_group = df.groupby(['AgeGroup', 'Sex']).size().unstack()

# Plot the stacked bar chart
age_sex_group.plot(kind='bar', stacked=True, figsize=(10,7))
plt.title('Stacked Bar Chart for Men vs Women by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-29-447ba3287ffc>:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_sex_group = df.groupby(['AgeGroup', 'Sex']).size().unstack()

# %%
# Filter men by age group
men_age_group = df[df['Sex'] == 'M']['AgeGroup'].value_counts()

# Plot pie chart
plt.figure(figsize=(10,7))
men_age_group.plot.pie(autopct='%1.1f%%')
plt.title('Men by Age Group')
plt.show()

# %%
# Filter women by age group
women_age_group = df[df['Sex'] == 'F']['AgeGroup'].value_counts()

# Plot pie chart
plt.figure(figsize=(10,7))
women_age_group.plot.pie(autopct='%1.1f%%')
plt.title('Women by Age Group')
plt.show()

# %%
# Plot histogram for men by age
plt.figure(figsize=(10,7))
plt.hist(df_men['Age'], bins=10, edgecolor='black')
plt.title('Histogram for Men by Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot histogram for women by age
plt.figure(figsize=(10,7))
plt.hist(df_women['Age'], bins=10, edgecolor='black')
plt.title('Histogram for Women by Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
